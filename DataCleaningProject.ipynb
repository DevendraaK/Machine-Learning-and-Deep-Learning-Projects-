# %% [markdown]
# <a href="https://colab.research.google.com/github/DevendraaK/Machine-Learning-and-Deep-Learning-Projects-/blob/main/DataCleaningProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-d622d1c2-67f9-4c7f-9439-370eb67cd2d5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d622d1c2-67f9-4c7f-9439-370eb67cd2d5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dataset.csv to dataset.csv

# %%
df=pd.read_csv('dataset.csv')

# %%
df.shape
# Out:
# (2514, 10)

# %%
df.head()
# Out:
#                  Name Twitter_username  ... Instagram_username   Political_party
# 0  A. Donald McEachin      RepMcEachin  ...        repmceachin  Democratic Party
# 1    Aaron Michlewitz    RepMichlewitz  ...                NaN  Democratic Party
# 2        Aaron Peskin      AaronPeskin  ...          apeskin52  Democratic Party
# 3          Aaron Peña        AaronPena  ...                NaN  Republican Party
# 4        Aaron Schock      aaronschock  ...        aaronschock  Republican Party
#
# [5 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2514 entries, 0 to 2513
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                2514 non-null   object
#  1   Twitter_username    2514 non-null   object
#  2   Account_start_time  2123 non-null   object
#  3   Account_ID          2183 non-null   object
#  4   Sex                 2514 non-null   object
#  5   Birthplace          2513 non-null   object
#  6   Birthday            2491 non-null   object
#  7   Age                 2491 non-null   float64
#  8   Instagram_username  1167 non-null   object
#  9   Political_party     2514 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 196.5+ KB

# %%
plt.figure(figsize=(25,25))
sns.heatmap(df.isnull())

# %%
null_var=(df.isnull().sum()/df.shape[0])*100
null_var
# Out:
# Name                   0.000000
# Twitter_username       0.000000
# Account_start_time    15.552904
# Account_ID            13.166269
# Sex                    0.000000
# Birthplace             0.039777
# Birthday               0.914877
# Age                    0.914877
# Instagram_username    53.579952
# Political_party        0.000000
# dtype: float64

# %%
drop_columns=null_var[null_var>1].keys()
print(drop_columns)
# Out:
# Index(['Account_start_time', 'Account_ID', 'Instagram_username'], dtype='object')

# %%
df2_drop_clm=df.drop(columns=drop_columns)
df2_drop_clm
# Out:
#                     Name Twitter_username  ...   Age    Political_party
# 0     A. Donald McEachin      RepMcEachin  ...  59.0   Democratic Party
# 1       Aaron Michlewitz    RepMichlewitz  ...  42.0   Democratic Party
# 2           Aaron Peskin      AaronPeskin  ...  56.0   Democratic Party
# 3             Aaron Peña        AaronPena  ...  61.0   Republican Party
# 4           Aaron Schock      aaronschock  ...  39.0   Republican Party
# ...                  ...              ...  ...   ...                ...
# 2509       Yvette Clarke  RepYvetteClarke  ...  55.0   Democratic Party
# 2510      Yvette Herrell  yvette4congress  ...  56.0   Republican Party
# 2511     Zephyr Teachout   zephyrteachout  ...  49.0   Democratic Party
# 2512         Zoe Lofgren    RepZoeLofgren  ...  72.0   Democratic Party
# 2513       Zoltan Istvan    zoltan_istvan  ...  47.0  Libertarian Party
#
# [2514 rows x 7 columns]

# %%
sns.heatmap(df2_drop_clm.isnull())

# %%
df3_drop_rows=df2_drop_clm.dropna()

# %%
df3_drop_rows.shape
# Out:
# (2490, 7)

# %%
plt.figure(figsize=(25,25))
sns.heatmap(df3_drop_rows.isnull())
