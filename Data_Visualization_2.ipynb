# %% [markdown]
# <a href="https://colab.research.google.com/github/DevendraaK/Machine-Learning-and-Deep-Learning-Projects-/blob/main/Data_Visualization_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=['India','USA','UK','Japan','China','UAE','pakistan']
y=[33,66,23,45,78,67,1]
plt.pie(y,autopct="%.2f",labels=x)
plt.show()
